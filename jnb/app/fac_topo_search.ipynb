# %% [markdown]
# # CPRN 应用实例
#
# ---
#
# author : seika<seika@live.ca>
# last update : 2025-11-05
#
# ---

# %% [markdown]
# ## ⓪ Load CPRN Model

# %%
# %load_ext autoreload
# %reload_ext autoreload
# %autoreload 2

import pandas as pd

PATH_FOLDER_CPRN_PAYLOAD : str = r'/Users/seika/sync/lab_works/taisl/cprn_payload/cprn_models/CPRN_JS_V417/'
MODELNAME_CPRN_BASE : str = 'CPRN_DG_FAC_EMBD_JS_FUSIONMAP_V417_251105_baaac0479ee7a4ea48b18a07d053cabc754eea0a5f7f696bc5a7437f50ec7e00.tar.gz'
MODELNAME_CPRN_FACBIND_SHORT : str = 'CPRN_DG_FAC_EMBD_JS_FUSIONMAP_SHORTEN_V417_251105_ab5083814993673ac4ecd9863a3013d8428c9c62743d44785df13f1b31dbbacd.tar.gz'

# %%
from calendar import c
from cprn.data.pickle import PickleIO
dg_cprn_base = PickleIO.load_from_pickle(PATH_FOLDER_CPRN_PAYLOAD + MODELNAME_CPRN_BASE, compress=True)
print(dg_cprn_base)

dg_cprn_facbind_short = PickleIO.load_from_pickle(PATH_FOLDER_CPRN_PAYLOAD + MODELNAME_CPRN_FACBIND_SHORT, compress=True)
print(dg_cprn_facbind_short)
# Out:
# File hash checking : baaac0479ee7a4ea48b18a07d053cabc754eea0a5f7f696bc5a7437f50ec7e00 : passed
# DiGraph with 219848 nodes and 223773 edges
# File hash checking : ab5083814993673ac4ecd9863a3013d8428c9c62743d44785df13f1b31dbbacd : passed
# DiGraph with 45050 nodes and 48975 edges

# %% [markdown]
# ## 🅰 Retrieve Facility List

# %%
from cprn.model.topo.topo_search import CprnTopoSearch as CTS
df_facs = CTS.list_fac_df(dg_cprn_facbind_short)

print(f"fetched {len(df_facs)} facilities from embeded CPRN model")

df_facs.sample(2)
# Out:
# fetched 13751 facilities from embeded CPRN model
#                   vtx_fac            fac_code fac_type  fac_name  \
# 12176  WTT7ZSJJ0D9F002749  WTT7ZSJJ0D9F002749      DC2       1|2
# 9518   WTUFRKPKUK6K000932     G0002A10000GY0W      SA2  高邮服务区(西)
#
#                   fac_ghz road_code mdir  dist_cp fac_rp_src
# 12176                 NaN       NaN  NaN      NaN        NaN
# 9518   WTUFRKV3ZJUV-00000       NaN  NaN      NaN        NaN

# %%
df_facs.query(" fac_name == '麒麟枢纽' ")
# Out:
#                   vtx_fac          fac_code fac_type fac_name  \
# 103    WTSW6TSUSDQV003645  G0042K02790000ZZ     IC1E     麒麟枢纽
# 108    WTSW6WQFFS8X003188  G0042K02790000ZZ     IC2E     麒麟枢纽
# 1734   WTSW6TVD0386002724  G0042K02790000ZZ     IC2E     麒麟枢纽
# 3139   WTSW6SG45PUG003864  G0042K02790000ZZ     IC1E     麒麟枢纽
# 3680   WTSW6WZWVWPW003029  G0042K02790000ZZ     IC2E     麒麟枢纽
# 4070   WTSW6VE09HE8002518  G0042K02790000ZZ     IC1E     麒麟枢纽
# 4467   WTSW6TX7H9JR002599  G0042K02790000ZZ     IC2E     麒麟枢纽
# 5076   WTSW6WZWF28H003036  G0042K02790000ZZ     IC1E     麒麟枢纽
# 5386   WTSW6V7R8DZ8002509  G0042K02790000ZZ     IC2E     麒麟枢纽
# 5924   WTSW6VB0S54G002536  G0042K02790000ZZ     IC1E     麒麟枢纽
# 6170   WTSW6SG5D8SB003846  G0042K02790000ZZ     IC2E     麒麟枢纽
# 6255   WTSW6TKJBDGP003821  G0042K02790000ZZ     IC2E     麒麟枢纽
# 8631   WTSW6TFSCEYY002806  G0042K02790000ZZ     IC1E     麒麟枢纽
# 9812   WTSW6QP9Y2YT002944  G0042K02790000ZZ     IC1E     麒麟枢纽
# 10022  WTSW6W1877Y8002924  G0042K02790000ZZ     IC2E     麒麟枢纽
# 12155  WTSW6WJRJUGY003417  G0042K02790000ZZ     IC1E     麒麟枢纽
#
#                   fac_ghz  road_code mdir     dist_cp fac_rp_src
# 103    WTSW6TV4PQG0-00000  G25|G2503  BWD  115.605957       algo
# 108    WTSW6TV4PQG0-00000        UNK  FWD  379.383948       algo
# 1734   WTSW6TV4PQG0-00000        G42  FWD   36.262444       algo
# 3139   WTSW6TV4PQG0-00000  G25|G2503  BWD  668.356819       algo
# 3680   WTSW6TV4PQG0-00000  G25|G2503  BWD  768.086811       algo
# 4070   WTSW6TV4PQG0-00000        G42  FWD  774.593519       algo
# 4467   WTSW6TV4PQG0-00000        UNK  FWD  312.364614       algo
# 5076   WTSW6TV4PQG0-00000  G25|G2503  FWD  759.320371       algo
# 5386   WTSW6TV4PQG0-00000        G42  BWD  809.444530       algo
# 5924   WTSW6TV4PQG0-00000        UNK  FWD  377.115910       algo
# 6170   WTSW6TV4PQG0-00000  G25|G2503  FWD  647.280622       algo
# 6255   WTSW6TV4PQG0-00000        UNK  FWD  283.011572       algo
# 8631   WTSW6TV4PQG0-00000        UNK  BWD  350.720477       algo
# 9812   WTSW6TV4PQG0-00000        G42  BWD  731.209519       algo
# 10022  WTSW6TV4PQG0-00000        G42  FWD  484.067175       algo
# 12155  WTSW6TV4PQG0-00000        UNK  FWD  247.837718       algo

# %% [markdown]
# ## 设施检索

# %%
df_facs.query(" fac_code == 'G0042K02790000ZZ' and fac_type == 'IC2E' ")
# Out:
#                   vtx_fac          fac_code fac_type fac_name  \
# 108    WTSW6WQFFS8X003188  G0042K02790000ZZ     IC2E     麒麟枢纽
# 1734   WTSW6TVD0386002724  G0042K02790000ZZ     IC2E     麒麟枢纽
# 3680   WTSW6WZWVWPW003029  G0042K02790000ZZ     IC2E     麒麟枢纽
# 4467   WTSW6TX7H9JR002599  G0042K02790000ZZ     IC2E     麒麟枢纽
# 5386   WTSW6V7R8DZ8002509  G0042K02790000ZZ     IC2E     麒麟枢纽
# 6170   WTSW6SG5D8SB003846  G0042K02790000ZZ     IC2E     麒麟枢纽
# 6255   WTSW6TKJBDGP003821  G0042K02790000ZZ     IC2E     麒麟枢纽
# 10022  WTSW6W1877Y8002924  G0042K02790000ZZ     IC2E     麒麟枢纽
#
#                   fac_ghz  road_code mdir     dist_cp fac_rp_src
# 108    WTSW6TV4PQG0-00000        UNK  FWD  379.383948       algo
# 1734   WTSW6TV4PQG0-00000        G42  FWD   36.262444       algo
# 3680   WTSW6TV4PQG0-00000  G25|G2503  BWD  768.086811       algo
# 4467   WTSW6TV4PQG0-00000        UNK  FWD  312.364614       algo
# 5386   WTSW6TV4PQG0-00000        G42  BWD  809.444530       algo
# 6170   WTSW6TV4PQG0-00000  G25|G2503  FWD  647.280622       algo
# 6255   WTSW6TV4PQG0-00000        UNK  FWD  283.011572       algo
# 10022  WTSW6TV4PQG0-00000        G42  FWD  484.067175       algo

# %%
start_vtx = 'WTSW6TKJBDGP003821' 
lst_fac_search = CTS.fac_bfs_depth_v2(DG = dg_cprn_facbind_short, start_node = start_vtx, 
    fac_types = ['G1','G2','G3'],  direction = 'downstream', 
    max_depth = 1, max_dist = 20000, mark_max_dist = True,
    query_avoid_fac=[],
    query_avoid_edge = "rtype in ['SA'] or (knd == 'ST' and cls == 'MR')",
    verbose = True)

len(lst_fac_search)

df =  pd.DataFrame(lst_fac_search)
# df.query("reach_max_dist != True")
df
# Out:
# 2025-11-06 09:10:48.552 | INFO     | cprn.model.topo.topo_search:fac_bfs_depth_v2:489 - 🏰 Facility G250332003000210010 at vtx WTSW67RDR16E005271 found
# 2025-11-06 09:10:48.553 | INFO     | cprn.model.topo.topo_search:fac_bfs_depth_v2:484 - 📛 Stop Criteria Activated: Max depth exceeds 1, stop searching at WTSW1U7XZ2WF002724
# 2025-11-06 09:10:48.553 | INFO     | cprn.model.topo.topo_search:fac_bfs_depth_v2:527 - 🚫 Avoid Edge WTSW61XVYP04003430 -> WTSW61SPNZC7002068, {'edge_id': [154921, 154920, 152794, 152795, 9241, 45400], 'weight': 483.89000000000004, 'rcode': 'G25|G2503', 'knd': 'ST', 'cls': 'MR', 'rtype': 'NA', 'mdir': 'NA', 'lane': 2.0, 'edge_code': 'WTSW61XVYP04003430_WTSW61SPNZC7002068'}
#    depth       vtx_intvl_src       vtx_intvl_tgt  interval_weight  \
# 0      1  WTSW6TKJBDGP003821  WTSW67RDR16E005271          1414.33
#
#    cumulative_weight                                     interval_edges  \
# 0            1414.33  [WTSW6TKJBDGP003821_WTSW6T7GKCG9003784, WTSW6T...
#
#                                     cumulative_edges  reach_max_depth  \
# 0  [WTSW6TKJBDGP003821_WTSW6T7GKCG9003784, WTSW6T...             True
#
#               vtx_fac             fac_code fac_type   fac_name  \
# 0  WTSW67RDR16E005271  G250332003000210010       G1  麒麟枢纽至开城路1
#
#               fac_ghz
# 0  WTSW67RDSS5U-00000

# %% [markdown]
# ## BACKWARD SEARCH

# %%
start_vtx = 'WTSW6TKJBDGP003821' 

lst_fac_search = CTS.fac_bfs_depth_v2(DG = dg_cprn_facbind_short, start_node = start_vtx, 
    fac_types = ['G1','G2','G3'],  direction = 'upstream', 
    max_depth = 1, max_dist = 10000, mark_max_dist = True,
    # query_avoid_edge = "rtype in ['SA'] or (knd == 'ST' and cls == 'MR')",
    verbose = True)

import pandas as pd
df_res = pd.DataFrame(lst_fac_search)
# df.query("is_fac  == True")
df_res
# Out:
# 2025-11-06 09:11:16.689 | INFO     | cprn.model.topo.topo_search:fac_bfs_depth_v2:489 - 🏰 Facility G004232001002310010 at vtx WTSW7JH2CM9E002291 found
# 2025-11-06 09:11:16.690 | INFO     | cprn.model.topo.topo_search:fac_bfs_depth_v2:484 - 📛 Stop Criteria Activated: Max depth exceeds 1, stop searching at WTSW7SMZZYWH003418
# 2025-11-06 09:11:16.691 | INFO     | cprn.model.topo.topo_search:fac_bfs_depth_v2:484 - 📛 Stop Criteria Activated: Max depth exceeds 1, stop searching at WTSW7J4FB5HS002377
# 2025-11-06 09:11:16.691 | INFO     | cprn.model.topo.topo_search:fac_bfs_depth_v2:457 - 📛 Stop Criteria Activated: Traverse distance exceeds 10000, stop searching at WTSW0YVDN01Z001818
# 2025-11-06 09:11:16.692 | INFO     | cprn.model.topo.topo_search:fac_bfs_depth_v2:457 - 📛 Stop Criteria Activated: Traverse distance exceeds 10000, stop searching at WTSW8GQP5PH8005809
# 2025-11-06 09:11:16.692 | INFO     | cprn.model.topo.topo_search:fac_bfs_depth_v2:457 - 📛 Stop Criteria Activated: Traverse distance exceeds 10000, stop searching at WTSW8GN47286005145
#    depth       vtx_intvl_src       vtx_intvl_tgt  interval_weight  \
# 0      1  WTSW6TKJBDGP003821  WTSW7JH2CM9E002291          2555.71
# 1      0  WTSW6TKJBDGP003821  WTSW0YVDN01Z001818         10095.95
# 2      0  WTSW6TKJBDGP003821  WTSW8GQP5PH8005809         10025.70
# 3      0  WTSW6TKJBDGP003821  WTSW8GN47286005145         10085.03
#
#    cumulative_weight                                     interval_edges  \
# 0            2555.71  [WTSW6TZKJ6M0002555_WTSW6TKJBDGP003821, WTSW6T...
# 1           10095.95  [WTSW6T7VYY3X003807_WTSW6TKJBDGP003821, WTSW6T...
# 2           10025.70  [WTSW6T7VYY3X003807_WTSW6TKJBDGP003821, WTSW6T...
# 3           10085.03  [WTSW6T7VYY3X003807_WTSW6TKJBDGP003821, WTSW6T...
#
#                                     cumulative_edges reach_max_depth  \
# 0  [WTSW6TZKJ6M0002555_WTSW6TKJBDGP003821, WTSW6T...            True
# 1  [WTSW6T7VYY3X003807_WTSW6TKJBDGP003821, WTSW6T...             NaN
# 2  [WTSW6T7VYY3X003807_WTSW6TKJBDGP003821, WTSW6T...             NaN
# 3  [WTSW6T7VYY3X003807_WTSW6TKJBDGP003821, WTSW6T...             NaN
#
#               vtx_fac             fac_code fac_type    fac_name  \
# 0  WTSW7JH2CM9E002291  G004232001002310010       G1  阳山园博园至麒麟枢纽
# 1                 NaN                  NaN      NaN         NaN
# 2                 NaN                  NaN      NaN         NaN
# 3                 NaN                  NaN      NaN         NaN
#
#               fac_ghz reach_max_dist
# 0  WTSW7JH39ZY3-00000            NaN
# 1                 NaN           True
# 2                 NaN           True
# 3                 NaN           True

# %%
df_res.iloc[2]['cumulative_edges']
# Out:
# ['WTSW6T7VYY3X003807_WTSW6TKJBDGP003821',
#  'WTSW6TFS9MWC002795_WTSW6T7VYY3X003807',
#  'WTSW6TFSCEYY002806_WTSW6TFS9MWC002795',
#  'WTSW6TCWPU64002822_WTSW6TFSCEYY002806',
#  'WTSW6QP8VZP8002896_WTSW6TCWPU64002822',
#  'WTSW6QP9Y2YT002944_WTSW6QP8VZP8002896',
#  'WTSW6QP4289W002949_WTSW6QP9Y2YT002944',
#  'WTSW3V7H9ZPN002552_WTSW6QP4289W002949',
#  'WTSW3V75FX3C002519_WTSW3V7H9ZPN002552',
#  'WTSW3V64MWYM002332_WTSW3V75FX3C002519',
#  'WTSW3V30BSGD002220_WTSW3V64MWYM002332',
#  'WTSW3V209VQK002171_WTSW3V30BSGD002220',
#  'WTSW3TR8YUKX002197_WTSW3V209VQK002171',
#  'WTSW3TQ8YB2F002303_WTSW3TR8YUKX002197',
#  'WTSW3TQ9W8F5002329_WTSW3TQ8YB2F002303',
#  'WTSW3TK91DRP002570_WTSW3TQ9W8F5002329',
#  'WTSW3T73H9KY002609_WTSW3TK91DRP002570',
#  'WTSW3T228CV0002480_WTSW3T73H9KY002609',
#  'WTSW3T22146Q002448_WTSW3T228CV0002480',
#  'WTSW3T0P9PDM002403_WTSW3T22146Q002448',
#  'WTSW3MPZ694F002366_WTSW3T0P9PDM002403',
#  'WTSW3MPZ1W0C002358_WTSW3MPZ694F002366',
#  'WTSW3MPHMX11002226_WTSW3MPZ1W0C002358',
#  'WTSW3MP526SB002187_WTSW3MPHMX11002226',
#  'WTSW3MNFZPFD002179_WTSW3MP526SB002187',
#  'WTSW3KYM2UUC001970_WTSW3MNFZPFD002179',
#  'WTSW3M7B4GYN002946_WTSW3KYM2UUC001970',
#  'WTSW3M7C77QK002959_WTSW3M7B4GYN002946',
#  'WTSW3M7C3KQN002957_WTSW3M7C77QK002959',
#  'WTSW3M7GGRB7002974_WTSW3M7C3KQN002957',
#  'WTSW3M7GUR2V002984_WTSW3M7GGRB7002974',
#  'WTSW3MEEJED9003099_WTSW3M7GUR2V002984',
#  'WTSW3MEERYH9003122_WTSW3MEEJED9003099',
#  'WTSW3MEEXHZW003124_WTSW3MEERYH9003122',
#  'WTSW3MESSN43003138_WTSW3MEEXHZW003124',
#  'WTSW3MFGRT2T003179_WTSW3MESSN43003138',
#  'WTSW90DBRJTG003813_WTSW3MFGRT2T003179',
#  'WTSW90CYQQB0003537_WTSW90DBRJTG003813',
#  'WTSW90CZEX57003526_WTSW90CYQQB0003537',
#  'WTSW9134PQ31003480_WTSW90CZEX57003526',
#  'WTSW912YXB52003557_WTSW9134PQ31003480',
#  'WTSW8FX6ERQK005326_WTSW912YXB52003557',
#  'WTSW8FXK3JBK005402_WTSW8FX6ERQK005326',
#  'WTSW8FXKB3PV005419_WTSW8FXK3JBK005402',
#  'WTSW8FYYDSS0005763_WTSW8FXKB3PV005419',
#  'WTSW8FYZ3DSU005778_WTSW8FYYDSS0005763',
#  'WTSW8GN9QXGM005821_WTSW8FYZ3DSU005778',
#  'WTSW8GNT18KB005866_WTSW8GN9QXGM005821',
#  'WTSW8GNT3J3Y005871_WTSW8GNT18KB005866',
#  'WTSW8GNQRC47005875_WTSW8GNT3J3Y005871',
#  'WTSW8GNQYYH9005873_WTSW8GNQRC47005875',
#  'WTSW8GQP5PH8005809_WTSW8GNQYYH9005873']

# %% [markdown]
# ## 设施检索(使用优化图+获取边几何)

# %%
from cprn.model.topo.topo_search import CprnTopoSearch as CTS
df_facs = CTS.list_fac_df(dg_cprn_facbind_short)

print(f"fetched {len(df_facs)} facilities from embeded CPRN model")
# Out:
# fetched 13751 facilities from embeded CPRN model

# %%
df_facs.sample(4)
df_facs.query(" fac_code == 'G004232001001920010' ")
# Out:
#                  vtx_fac             fac_code fac_type  fac_name  \
# 2317  WTSWRFPBHFTR004062  G004232001001920010       G1  汤山至句容城区1
#
#                  fac_ghz road_code mdir  dist_cp fac_rp_src
# 2317  WTSWRCZZHZ8X-00000       NaN  NaN      NaN        NaN

# %%
lst_fac_search = CTS.fac_bfs_depth_v2(DG = dg_cprn_facbind_short, start_node = 'WTSWRFPBHFTR004062', 
    fac_types = ['G1'],  direction = 'downstream', 
    max_depth = 3, max_dist = 10000, mark_max_dist = False,
    query_avoid_fac=[],
    query_avoid_edge = "rtype in ['SA'] or (knd == 'ST' and cls == 'MR')",
    verbose = True)

print(len(lst_fac_search))

df = pd.DataFrame(lst_fac_search)
df
# Out:
# 2025-11-06 09:42:23.149 | INFO     | cprn.model.topo.topo_search:fac_bfs_depth_v2:447 - Start node WTSWRFPBHFTR004062 is a suitable facility, add as depth 0 😄
# 2025-11-06 09:42:23.149 | INFO     | cprn.model.topo.topo_search:fac_bfs_depth_v2:506 - 🏰 Facility G004232001001920010 at vtx WTSWRFPBHFTR004062 found but already visited
# 2025-11-06 09:42:23.151 | INFO     | cprn.model.topo.topo_search:fac_bfs_depth_v2:489 - 🏰 Facility G004232001001820020 at vtx WTSY29DSBCUD005515 found
# 2025-11-06 09:42:23.151 | INFO     | cprn.model.topo.topo_search:fac_bfs_depth_v2:489 - 🏰 Facility G004232001001820010 at vtx WTSY38VW8T2R004140 found
# 2025-11-06 09:42:23.152 | INFO     | cprn.model.topo.topo_search:fac_bfs_depth_v2:527 - 🚫 Avoid Edge WTSY233FC5GS005635 -> WTSY2364EMXE005712, {'edge_id': [15305, 118040], 'weight': 42.25, 'rcode': 'G42', 'knd': 'ST', 'cls': 'MR', 'rtype': 'NA', 'mdir': 'NA', 'lane': 3.0, 'edge_code': 'WTSY233FC5GS005635_WTSY2364EMXE005712'}
# 2025-11-06 09:42:23.152 | INFO     | cprn.model.topo.topo_search:fac_bfs_depth_v2:457 - 📛 Stop Criteria Activated: Traverse distance exceeds 10000, stop searching at WTSYK355TUW7004831
# 2025-11-06 09:42:23.153 | INFO     | cprn.model.topo.topo_search:fac_bfs_depth_v2:527 - 🚫 Avoid Edge WTSY6069JQQS003320 -> WTSY6069GY3C003292, {'edge_id': [154537], 'weight': 16.56, 'rcode': 'G42', 'knd': 'ST', 'cls': 'MR', 'rtype': 'NA', 'mdir': 'BWD', 'lane': 1.0, 'edge_code': 'WTSY6069JQQS003320_WTSY6069GY3C003292'}
# 2025-11-06 09:42:23.153 | INFO     | cprn.model.topo.topo_search:fac_bfs_depth_v2:527 - 🚫 Avoid Edge WTSY6068EZZ4003334 -> WTSY6063RBE8003314, {'edge_id': [153951], 'weight': 19.41, 'rcode': 'G42', 'knd': 'ST', 'cls': 'MR', 'rtype': 'NA', 'mdir': 'NA', 'lane': 2.0, 'edge_code': 'WTSY6068EZZ4003334_WTSY6063RBE8003314'}
# 3
#    depth       vtx_intvl_src       vtx_intvl_tgt  interval_weight  \
# 0      0  WTSWRFPBHFTR004062  WTSWRFPBHFTR004062             0.00
# 1      1  WTSWRFPBHFTR004062  WTSY29DSBCUD005515          2429.93
# 2      2  WTSY29DSBCUD005515  WTSY38VW8T2R004140          4578.80
#
#    cumulative_weight                                     interval_edges  \
# 0               0.00                                                 []
# 1            2429.93  [WTSWRFPBHFTR004062_WTSY21FW81EK003670, WTSY21...
# 2            7008.73  [WTSY29DSBCUD005515_WTSY38FYKF2X003933, WTSY38...
#
#                                     cumulative_edges             vtx_fac  \
# 0                                                 []  WTSWRFPBHFTR004062
# 1  [WTSWRFPBHFTR004062_WTSY21FW81EK003670, WTSY21...  WTSY29DSBCUD005515
# 2  [WTSWRFPBHFTR004062_WTSY21FW81EK003670, WTSY21...  WTSY38VW8T2R004140
#
#               fac_code fac_type  fac_name             fac_ghz reach_max_depth
# 0  G004232001001920010       G1  汤山至句容城区1  WTSWRCZZHZ8X-00000             NaN
# 1  G004232001001820020       G1  句容城区至句容2  WTSY29DECN29-00000           False
# 2  G004232001001820010       G1  句容城区至句容1  WTSY38VTB6ZG-00000           False

# %% [markdown]
# ## 利用 设施 BFS 获取设施附近道路geom

# %%
from cprn.model.topo.topo_search import CprnTopoSearch as CTS
lst_fac_search = CTS.fac_bfs_depth(DG = dg_cprn_facbind_short, start_node = 'WTSWRFPBHFTR004062', 
    fac_types = ['IC2E'],  direction = 'downstream', 
    max_depth = 2, max_dist = 50000, 
    mark_max_dist = True,
    query_avoid_fac=[],
    query_avoid_edge = "", #"rtype in ['SA'] or (knd == 'ST' and cls == 'MR')",
    version = 'v2',
    verbose = True)

df = pd.DataFrame(lst_fac_search)
df
# Out:
# 2025-11-06 10:06:29.205 | INFO     | cprn.model.topo.topo_search:fac_bfs_depth:194 - Using version v2 of `fac_bfs_depth`
# 2025-11-06 10:06:29.206 | INFO     | cprn.model.topo.topo_search:fac_bfs_depth_v2:489 - 🏰 Facility G0042K02350000DT at vtx WTSYM49R3ZEQ003259 found
# 2025-11-06 10:06:29.206 | INFO     | cprn.model.topo.topo_search:fac_bfs_depth_v2:506 - 🏰 Facility G0042K02350000DT at vtx WTSYM4V8E4KZ003035 found but already visited
# 2025-11-06 10:06:29.207 | INFO     | cprn.model.topo.topo_search:fac_bfs_depth_v2:506 - 🏰 Facility G0042K02350000DT at vtx WTSYKUQ3TVTS003978 found but already visited
# 2025-11-06 10:06:29.207 | INFO     | cprn.model.topo.topo_search:fac_bfs_depth_v2:506 - 🏰 Facility G0042K02350000DT at vtx WTSYKGW32GZK004493 found but already visited
# 2025-11-06 10:06:29.207 | INFO     | cprn.model.topo.topo_search:fac_bfs_depth_v2:489 - 🏰 Facility G0042K02300000ZJ at vtx WTSYQK1R1N8Y003139 found
# 2025-11-06 10:06:29.208 | INFO     | cprn.model.topo.topo_search:fac_bfs_depth_v2:506 - 🏰 Facility G0042K02300000ZJ at vtx WTSYQEB2NDPB002946 found but already visited
# 2025-11-06 10:06:29.210 | INFO     | cprn.model.topo.topo_search:fac_bfs_depth_v2:489 - 🏰 Facility G0042K02790000ZZ at vtx WTSW6TVD0386002724 found
# 2025-11-06 10:06:29.211 | INFO     | cprn.model.topo.topo_search:fac_bfs_depth_v2:484 - 📛 Stop Criteria Activated: Max depth exceeds 2, stop searching at WTTN4M4UGU8W001377
# 2025-11-06 10:06:29.211 | INFO     | cprn.model.topo.topo_search:fac_bfs_depth_v2:506 - 🏰 Facility G0042K02790000ZZ at vtx WTSW6WQFFS8X003188 found but already visited
# 2025-11-06 10:06:29.211 | INFO     | cprn.model.topo.topo_search:fac_bfs_depth_v2:506 - 🏰 Facility G0042K02790000ZZ at vtx WTSW6TKJBDGP003821 found but already visited
# 2025-11-06 10:06:29.212 | INFO     | cprn.model.topo.topo_search:fac_bfs_depth_v2:506 - 🏰 Facility G0042K02790000ZZ at vtx WTSW6W1877Y8002924 found but already visited
# 2025-11-06 10:06:29.212 | INFO     | cprn.model.topo.topo_search:fac_bfs_depth_v2:457 - 📛 Stop Criteria Activated: Traverse distance exceeds 50000, stop searching at WTSUTK9DMX3W001646
# 2025-11-06 10:06:29.212 | INFO     | cprn.model.topo.topo_search:fac_bfs_depth_v2:484 - 📛 Stop Criteria Activated: Max depth exceeds 2, stop searching at WTTN4K3ZGS61002148
# 2025-11-06 10:06:29.212 | INFO     | cprn.model.topo.topo_search:fac_bfs_depth_v2:484 - 📛 Stop Criteria Activated: Max depth exceeds 2, stop searching at WTTN4MKKGUN8002080
# 2025-11-06 10:06:29.213 | INFO     | cprn.model.topo.topo_search:fac_bfs_depth_v2:506 - 🏰 Facility G0042K02790000ZZ at vtx WTSW6WZWVWPW003029 found but already visited
# 2025-11-06 10:06:29.213 | INFO     | cprn.model.topo.topo_search:fac_bfs_depth_v2:484 - 📛 Stop Criteria Activated: Max depth exceeds 2, stop searching at WTSYM505RRQH004025
# 2025-11-06 10:06:29.214 | INFO     | cprn.model.topo.topo_search:fac_bfs_depth_v2:506 - 🏰 Facility G0042K02790000ZZ at vtx WTSW6SG5D8SB003846 found but already visited
# 2025-11-06 10:06:29.215 | INFO     | cprn.model.topo.topo_search:fac_bfs_depth_v2:484 - 📛 Stop Criteria Activated: Max depth exceeds 2, stop searching at WTSYQ5T3V9KK003515
# 2025-11-06 10:06:29.215 | INFO     | cprn.model.topo.topo_search:fac_bfs_depth_v2:457 - 📛 Stop Criteria Activated: Traverse distance exceeds 50000, stop searching at WTSVSZ5TCQUE001458
# 2025-11-06 10:06:29.216 | INFO     | cprn.model.topo.topo_search:fac_bfs_depth_v2:457 - 📛 Stop Criteria Activated: Traverse distance exceeds 50000, stop searching at WTSZU16WEC4C001111
# 2025-11-06 10:06:29.216 | INFO     | cprn.model.topo.topo_search:fac_bfs_depth_v2:484 - 📛 Stop Criteria Activated: Max depth exceeds 2, stop searching at WTSW3MJMY6JZ002349
# 2025-11-06 10:06:29.217 | INFO     | cprn.model.topo.topo_search:fac_bfs_depth_v2:484 - 📛 Stop Criteria Activated: Max depth exceeds 2, stop searching at WTSW3KY4DDF3002686
# 2025-11-06 10:06:29.217 | INFO     | cprn.model.topo.topo_search:fac_bfs_depth_v2:484 - 📛 Stop Criteria Activated: Max depth exceeds 2, stop searching at WTSW3MG5PKJ2003150
# 2025-11-06 10:06:29.218 | INFO     | cprn.model.topo.topo_search:fac_bfs_depth_v2:484 - 📛 Stop Criteria Activated: Max depth exceeds 2, stop searching at WTSTC2C16MJD002333
# 2025-11-06 10:06:29.218 | INFO     | cprn.model.topo.topo_search:fac_bfs_depth_v2:484 - 📛 Stop Criteria Activated: Max depth exceeds 2, stop searching at WTSTC21EX9C7001921
# 2025-11-06 10:06:29.219 | INFO     | cprn.model.topo.topo_search:fac_bfs_depth_v2:484 - 📛 Stop Criteria Activated: Max depth exceeds 2, stop searching at WTSTC0YYW1J0001619
# 2025-11-06 10:06:29.220 | INFO     | cprn.model.topo.topo_search:fac_bfs_depth_v2:457 - 📛 Stop Criteria Activated: Traverse distance exceeds 50000, stop searching at WTSZK43T7CFB004217
# 2025-11-06 10:06:29.221 | INFO     | cprn.model.topo.topo_search:fac_bfs_depth_v2:457 - 📛 Stop Criteria Activated: Traverse distance exceeds 50000, stop searching at WTSXFCN6395Q001678
# 2025-11-06 10:06:29.221 | INFO     | cprn.model.topo.topo_search:fac_bfs_depth_v2:484 - 📛 Stop Criteria Activated: Max depth exceeds 2, stop searching at WTSW6TX7H9JR002599
#    depth       vtx_intvl_src       vtx_intvl_tgt  interval_weight  \
# 0      1  WTSWRFPBHFTR004062  WTSYM49R3ZEQ003259         22112.61
# 1      2  WTSWRFPBHFTR004062  WTSYQK1R1N8Y003139         26781.98
# 2      1  WTSWRFPBHFTR004062  WTSW6TVD0386002724         26064.10
# 3      2  WTSYM49R3ZEQ003259  WTSUTK9DMX3W001646         34939.58
# 4      2  WTSYM49R3ZEQ003259  WTSVSZ5TCQUE001458         28101.88
# 5      2  WTSYM49R3ZEQ003259  WTSZU16WEC4C001111         29951.33
# 6      2  WTSYM49R3ZEQ003259  WTSZK43T7CFB004217         29664.37
# 7      2  WTSWRFPBHFTR004062  WTSXFCN6395Q001678         53281.85
#
#    cumulative_weight                                     interval_edges  \
# 0           22112.61  [WTSWRFPBHFTR004062_WTSY21FW81EK003670, WTSY21...
# 1           26781.98  [WTSWRFPBHFTR004062_WTSY21FW81EK003670, WTSY21...
# 2           26064.10  [WTSWRFPBHFTR004062_WTSY21FW81EK003670, WTSY21...
# 3           57052.19  [WTSYM49R3ZEQ003259_WTSYM4BVM5JT003628, WTSYM4...
# 4           50214.49  [WTSYM49R3ZEQ003259_WTSYM4BVM5JT003628, WTSYM4...
# 5           52063.94  [WTSYM49R3ZEQ003259_WTSYM4BVM5JT003628, WTSYM4...
# 6           51776.98  [WTSYM49R3ZEQ003259_WTSYM4BVM5JT003628, WTSYM4...
# 7           53281.85  [WTSWRFPBHFTR004062_WTSY21FW81EK003670, WTSY21...
#
#                                     cumulative_edges reach_max_depth  \
# 0  [WTSWRFPBHFTR004062_WTSY21FW81EK003670, WTSY21...           False
# 1  [WTSWRFPBHFTR004062_WTSY21FW81EK003670, WTSY21...            True
# 2  [WTSWRFPBHFTR004062_WTSY21FW81EK003670, WTSY21...           False
# 3  [WTSWRFPBHFTR004062_WTSY21FW81EK003670, WTSY21...             NaN
# 4  [WTSWRFPBHFTR004062_WTSY21FW81EK003670, WTSY21...             NaN
# 5  [WTSWRFPBHFTR004062_WTSY21FW81EK003670, WTSY21...             NaN
# 6  [WTSWRFPBHFTR004062_WTSY21FW81EK003670, WTSY21...             NaN
# 7  [WTSWRFPBHFTR004062_WTSY21FW81EK003670, WTSY21...             NaN
#
#               vtx_fac          fac_code fac_type fac_name             fac_ghz  \
# 0  WTSYM49R3ZEQ003259  G0042K02350000DT     IC2E     丹徒枢纽  WTSYKFXYYQDZ-00000
# 1  WTSYQK1R1N8Y003139  G0042K02300000ZJ     IC2E     镇江枢纽  WTSYQ7C2WZHH-00000
# 2  WTSW6TVD0386002724  G0042K02790000ZZ     IC2E     麒麟枢纽  WTSW6TV4PQG0-00000
# 3                 NaN               NaN      NaN      NaN                 NaN
# 4                 NaN               NaN      NaN      NaN                 NaN
# 5                 NaN               NaN      NaN      NaN                 NaN
# 6                 NaN               NaN      NaN      NaN                 NaN
# 7                 NaN               NaN      NaN      NaN                 NaN
#
#   road_code mdir     dist_cp fac_rp_src reach_max_dist
# 0       UNK  BWD  176.648715       algo            NaN
# 1       S86  BWD  276.806755       algo            NaN
# 2       G42  FWD   36.262444       algo            NaN
# 3       NaN  NaN         NaN        NaN           True
# 4       NaN  NaN         NaN        NaN           True
# 5       NaN  NaN         NaN        NaN           True
# 6       NaN  NaN         NaN        NaN           True
# 7       NaN  NaN         NaN        NaN           True

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://sbds_dev:JD(3hf&fh@192.168.153.60/sbds_dev') # suck bds data obtain engine

from cprn.data.postgis import CprnPostgisRetriever
cprn_postgis_retriever = CprnPostgisRetriever(engine)

edge_codes = lst_fac_search[0]['cumulative_edges']
gdf_edges = cprn_postgis_retriever.get_edges_by_codes(
    tb_name = 'CPRN_dg_short_edges_geom_V414_jiangsu', edge_codes = edge_codes)

gdf_edges
# Out:
#                                 edge_code             src_vtx  \
# 0   WTSWRFPBHFTR004062_WTSY21FW81EK003670  WTSWRFPBHFTR004062
# 1   WTSY21FW81EK003670_WTSY21GNH2MD003630  WTSY21FW81EK003670
# 2   WTSY21GNH2MD003630_WTSY21GVNQYN003669  WTSY21GNH2MD003630
# 3   WTSY21GVNQYN003669_WTSY21V5CYX6003882  WTSY21GVNQYN003669
# 4   WTSY21V5CYX6003882_WTSY23WSEQ8H005462  WTSY21V5CYX6003882
# 5   WTSY23WSEQ8H005462_WTSY23XSW9YU005328  WTSY23WSEQ8H005462
# 6   WTSY23XSW9YU005328_WTSY299H91XV005305  WTSY23XSW9YU005328
# 7   WTSY299H91XV005305_WTSY29DSBCUD005515  WTSY299H91XV005305
# 8   WTSY29DSBCUD005515_WTSY38FYKF2X003933  WTSY29DSBCUD005515
# 9   WTSY38FYKF2X003933_WTSY38GYW41K003925  WTSY38FYKF2X003933
# 10  WTSY38GYW41K003925_WTSY38VW8T2R004140  WTSY38GYW41K003925
# 11  WTSY38VW8T2R004140_WTSY60DM1WQR003966  WTSY38VW8T2R004140
# 12  WTSY60DM1WQR003966_WTSY60EH9V3Y003892  WTSY60DM1WQR003966
# 13  WTSY60EH9V3Y003892_WTSY60SH0H68003839  WTSY60EH9V3Y003892
# 14  WTSY60SH0H68003839_WTSY60W7RH8J003747  WTSY60SH0H68003839
# 15  WTSY60W7RH8J003747_WTSY60WER5CV003737  WTSY60W7RH8J003747
# 16  WTSY60WER5CV003737_WTSY628G9FR5003657  WTSY60WER5CV003737
# 17  WTSY628G9FR5003657_WTSYK355TUW7004831  WTSY628G9FR5003657
# 18  WTSYK355TUW7004831_WTSYK97UWMWN005006  WTSYK355TUW7004831
# 19  WTSYK97UWMWN005006_WTSYK9KTY73R005042  WTSYK97UWMWN005006
# 20  WTSYK9KTY73R005042_WTSYK9MXT81Y005076  WTSYK9KTY73R005042
# 21  WTSYK9MXT81Y005076_WTSYKC8VEW4Z004965  WTSYK9MXT81Y005076
# 22  WTSYKC8VEW4Z004965_WTSYKC9QG9NQ004913  WTSYKC8VEW4Z004965
# 23  WTSYKC9QG9NQ004913_WTSYKCG5PS6K004651  WTSYKC9QG9NQ004913
# 24  WTSYKCG5PS6K004651_WTSYM42FFW48003697  WTSYKCG5PS6K004651
# 25  WTSYM42FFW48003697_WTSYM43VCJ7M003539  WTSYM42FFW48003697
# 26  WTSYM43V4GED003508_WTSYM49QK3MK003177  WTSYM43V4GED003508
# 27  WTSYM43VCJ7M003539_WTSYM43V4GED003508  WTSYM43VCJ7M003539
# 28  WTSYM49QK3MK003177_WTSYM49R3ZEQ003259  WTSYM49QK3MK003177
#
#                tgt_vtx rcode  mdir   weight   cls   knd   rtype  lane  \
# 0   WTSY21FW81EK003670   G42   BWD   338.52    MR    FW      NA   5.0
# 1   WTSY21GNH2MD003630   G42   BWD    83.01   BDG    FW      NA   5.0
# 2   WTSY21GVNQYN003669   G42   BWD   106.52    MR    FW      NA   6.0
# 3   WTSY21V5CYX6003882   G42   BWD   146.03    MR    FW      NA   4.0
# 4   WTSY23WSEQ8H005462   G42   BWD  1246.47    MR    FW      NA   5.0
# 5   WTSY23XSW9YU005328   G42   BWD   143.77    MR    FW      NA   4.0
# 6   WTSY299H91XV005305   G42   BWD   172.41    MR    FW      NA   6.0
# 7   WTSY29DSBCUD005515   G42   BWD   193.20    MR    FW      NA   5.0
# 8   WTSY38FYKF2X003933   G42   BWD  4239.26    MR    FW      NA   5.0
# 9   WTSY38GYW41K003925   G42   BWD   134.94   BDG    FW      NA   5.0
# 10  WTSY38VW8T2R004140   G42   BWD   204.60    MR    FW      NA   5.0
# 11  WTSY60DM1WQR003966   G42   BWD  1670.70    MR    FW      NA   5.0
# 12  WTSY60EH9V3Y003892   G42   BWD    98.28    MR    FW      NA   6.0
# 13  WTSY60SH0H68003839   G42   BWD   123.14    MR    FW      NA   4.0
# 14  WTSY60W7RH8J003747   G42   BWD   320.28    MR    FW      NA   5.0
# 15  WTSY60WER5CV003737   G42   BWD    32.66    MR    FW      NA   4.0
# 16  WTSY628G9FR5003657   G42   BWD   271.28    MR    FW      NA   6.0
# 17  WTSYK355TUW7004831   G42   BWD  8663.47    MR    FW      NA   5.0
# 18  WTSYK97UWMWN005006   G42   BWD  1150.89    MR    FW      NA   5.0
# 19  WTSYK9KTY73R005042   G42   BWD    99.25    MR    FW      NA   6.0
# 20  WTSYK9MXT81Y005076   G42   BWD   130.58    MR    FW      NA   4.0
# 21  WTSYKC8VEW4Z004965   G42   BWD   430.08    MR    FW      NA   5.0
# 22  WTSYKC9QG9NQ004913   G42   BWD    68.54    MR    FW      NA   4.0
# 23  WTSYKCG5PS6K004651   G42   BWD   256.44    MR    FW      NA   6.0
# 24  WTSYM42FFW48003697   G42   BWD   785.75    MR    FW      NA   5.0
# 25  WTSYM43VCJ7M003539   G42   BWD   136.11    MR    FW      NA   6.0
# 26  WTSYM49QK3MK003177  None   BWD   824.45    RX    FW  INTC_X   2.0
# 27  WTSYM43V4GED003508  None  None    16.95  None  None    None   NaN
# 28  WTSYM49R3ZEQ003259  None   BWD    25.03    RX    FW  INTC_X   1.0
#
#      con_type                                               geom
# 0        None  MULTILINESTRING Z ((119.17956 32.04713 40.6186...
# 1        None  MULTILINESTRING Z ((119.18313 32.04687 36.6958...
# 2        None  MULTILINESTRING Z ((119.184 32.04678 36.30456,...
# 3        None  MULTILINESTRING Z ((119.18511 32.04664 36.6942...
# 4        None  MULTILINESTRING Z ((119.18664 32.04642 38.8170...
# 5        None  MULTILINESTRING Z ((119.19974 32.04518 54.6242...
# 6        None  MULTILINESTRING Z ((119.20126 32.04516 53.2762...
# 7        None  MULTILINESTRING Z ((119.20309 32.04515 53.0489...
# 8        None  MULTILINESTRING Z ((119.20513 32.0452 55.14747...
# 9        None  MULTILINESTRING Z ((119.24959 32.04134 39.3316...
# 10       None  MULTILINESTRING Z ((119.25101 32.04138 39.2484...
# 11       None  MULTILINESTRING Z ((119.25318 32.0414 41.40343...
# 12       None  MULTILINESTRING Z ((119.27074 32.03977 39.6612...
# 13       None  MULTILINESTRING Z ((119.27178 32.03968 38.9244...
# 14       None  MULTILINESTRING Z ((119.27307 32.03959 38.3946...
# 15       None  MULTILINESTRING Z ((119.27646 32.03946 37.4690...
# 16       None  MULTILINESTRING Z ((119.27681 32.03946 37.3672...
# 17       None  MULTILINESTRING Z ((119.27968 32.03949 36.5720...
# 18       None  MULTILINESTRING Z ((119.37083 32.04225 48.3136...
# 19       None  MULTILINESTRING Z ((119.38287 32.0438 50.06222...
# 20       None  MULTILINESTRING Z ((119.38389 32.04401 50.4184...
# 21       None  MULTILINESTRING Z ((119.38523 32.04429 50.7602...
# 22       None  MULTILINESTRING Z ((119.38961 32.04535 49.6489...
# 23       None  MULTILINESTRING Z ((119.3903 32.04554 49.13366...
# 24       None  MULTILINESTRING Z ((119.39287 32.04628 46.5065...
# 25       None  MULTILINESTRING Z ((119.40055 32.049 36.96538,...
# 26       None  MULTILINESTRING Z ((119.40194 32.04937 35.0788...
# 27  sect_jump  MULTILINESTRING Z ((119.40186 32.04951 35.39, ...
# 28       None  MULTILINESTRING Z ((119.40132 32.05095 31.7728...

# %%
gdf_edges.set_crs(4326).explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4f8ba137e52961e037c23ceefd658d59 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4f8ba137e52961e037c23ceefd658d59&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4f8ba137e52961e037c23ceefd658d59 = L.map(
#                 &quot;map_4f8ba137e52961e037c23ceefd658d59&quot;,
#                 {
#                     center: [32.04459365947516, 119.29210573034842],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_4f8ba137e52961e037c23ceefd658d59);
#
#
#
#
#
#             var tile_layer_2be9c58f340e702f5635d86a0ce16d7a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2be9c58f340e702f5635d86a0ce16d7a.addTo(map_4f8ba137e52961e037c23ceefd658d59);
#
#
#             map_4f8ba137e52961e037c23ceefd658d59.fitBounds(
#                 [[32.03803579566316, 119.17955524222204], [32.05115152328716, 119.4046562184748]],
#                 {}
#             );
#
#
#         function geo_json_33012d20946a16d409a0d08801a5fe48_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_33012d20946a16d409a0d08801a5fe48_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_33012d20946a16d409a0d08801a5fe48_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_33012d20946a16d409a0d08801a5fe48_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_33012d20946a16d409a0d08801a5fe48_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_33012d20946a16d409a0d08801a5fe48.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_33012d20946a16d409a0d08801a5fe48_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_33012d20946a16d409a0d08801a5fe48 = L.geoJson(null, {
#                 onEachFeature: geo_json_33012d20946a16d409a0d08801a5fe48_onEachFeature,
#
#                 style: geo_json_33012d20946a16d409a0d08801a5fe48_styler,
#                 pointToLayer: geo_json_33012d20946a16d409a0d08801a5fe48_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_33012d20946a16d409a0d08801a5fe48_add (data) {
#             geo_json_33012d20946a16d409a0d08801a5fe48
#                 .addData(data);
#         }
#             geo_json_33012d20946a16d409a0d08801a5fe48_add({&quot;bbox&quot;: [119.17955524222204, 32.03803579566316, 119.4046562184748, 32.05115152328716], &quot;features&quot;: [{&quot;bbox&quot;: [119.17955524222204, 32.04687041656675, 119.1831253699942, 32.04713389195807], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[119.17955524222204, 32.04713389195807, 40.618604528483054], [119.1795834689974, 32.04713267589472, 40.588755638338], [119.1796620343546, 32.04712874843047, 40.50329391565
